# %% [markdown]
# # Lesson 01

# %% [markdown]
# ## Loading Data Sets
#
#
#
# ---

# %% [markdown]
# > Let's import the packages to load the data

# %%
import pandas as pd

# %% [markdown]
# > Now, Let's load our data from google drive

# %%
df = pd.read_csv('/content/drive/My Drive/Data/stock_data_version_2.csv')

# %% [markdown]
# > Let's Preview the data set

# %%
df
# Out:
#            Date  Adj Close (TSLA)  ...  Volume (TSLA)  Volume (SEDG)
# 0     7/11/2019         47.720001  ...       37572000         520000
# 1     7/12/2019         49.015999  ...       46002500         417500
# 2     7/15/2019         50.700001  ...       55000500         332800
# 3     7/16/2019         50.476002  ...       40745000         204000
# 4     7/17/2019         50.972000  ...       48823500         285300
# ..          ...               ...  ...            ...            ...
# 329  10/28/2020        406.019989  ...       25451400        1336400
# 330  10/29/2020        410.829987  ...       22655300        1099500
# 331  10/30/2020        388.040008  ...       42511300        1232700
# 332   11/2/2020        400.510010  ...       29021100        1805500
# 333   11/3/2020        423.899994  ...       34351700        8792700
#
# [334 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 334 entries, 0 to 333
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              334 non-null    object
#  1   Adj Close (TSLA)  334 non-null    float64
#  2   Adj Close (SEDG)  334 non-null    float64
#  3   Close (TSLA)      334 non-null    float64
#  4   Close (SEDG)      334 non-null    float64
#  5   High (TSLA)       334 non-null    float64
#  6   High (SEDG)       334 non-null    float64
#  7   Low (TSLA)        334 non-null    float64
#  8   Low (SEDG)        334 non-null    float64
#  9   Open (TSLA)       334 non-null    float64
#  10  Open (SEDG)       334 non-null    float64
#  11  Volume (TSLA)     334 non-null    int64
#  12  Volume (SEDG)     334 non-null    int64
# dtypes: float64(10), int64(2), object(1)
# memory usage: 34.0+ KB

# %% [markdown]
# > Finding total number of Rows and Columns

# %%
df.shape
# Out:
# (334, 13)

# %% [markdown]
# We have 334 **rows** and 13 **columns**

# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %% [markdown]
# Let's preview how much all of our data is distributed.
#
# But before we need to import the packages for visualization,

# %%
import seaborn as sns

# %% [markdown]
# Now, preview all of that data visually

# %%
# sns.pairplot(df)

# %% [markdown]
# Now, Let's preview each column of data individually

# %% [markdown]
# > Date vs TSLA (High) Bar plot

# %%
import matplotlib as plt

# %%
df['High (TSLA)'].plot(kind='bar',figsize=(15,8))

# %% [markdown]
# Histogram Plot

# %%
df['High (TSLA)'].plot(kind='hist', bins = 20,figsize=(10,6))

# %% [markdown]
# Let's preview the difference between TSLA (High) and TSLA (Low)

# %%
df[['High (TSLA)', 'Low (TSLA)']].plot(kind='area', figsize=(10,6))

# %% [markdown]
# Let's view the difference between TSLA (open) and TSLA (Close)

# %%
df[['Open (TSLA)', 'Close (TSLA)']].plot(kind='area', figsize=(10,6))

# %% [markdown]
# ## Movement of between openning and closing of stocks

# %%
import numpy as np

# %%
stock_open = np.array(df['Open (TSLA)']).T
stock_close = np.array(df['Close (TSLA)']).T

# %%
movements = stock_close - stock_open

# %%
movements
# Out:
# array([ 9.20028700e-02,  1.06599808e+00,  1.10000229e+00,  6.16001130e-01,
#        -1.61998750e-01, -3.01998140e-01,  4.98001100e-01, -6.13998410e-01,
#         6.92001350e-01,  1.14200211e+00, -9.36000820e-01,  2.24002840e-01,
#         1.73600006e+00,  1.87199783e+00, -2.77999870e-01, -1.75999832e+00,
#         5.97999570e-01, -2.55996710e-01, -2.25997920e-01,  1.38399887e+00,
#         7.70000460e-01, -2.08000180e-01, -7.96001430e-01,  1.23799896e+00,
#        -2.31800079e+00, -1.04400254e+00,  6.55998230e-01,  5.24002080e-01,
#        -3.51997370e-01, -2.36000060e-01, -1.30001060e-01, -1.71400070e+00,
#         2.79998780e-01, -3.31996920e-01,  3.80001070e-01,  5.41999810e-01,
#        -7.08000180e-01,  1.85997010e-01, -1.24199676e+00,  1.41600037e+00,
#         5.00030500e-02,  3.58001710e-01,  9.48001860e-01,  1.94399643e+00,
#        -3.66001130e-01, -3.51997370e-01, -6.38000490e-01,  4.64000700e-01,
# ...

# %%
movements = pd.Series(movements)

# %%
movements
# Out:
# 0       0.092003
# 1       1.065998
# 2       1.100002
# 3       0.616001
# 4      -0.161999
#          ...
# 329   -10.460022
# 330     0.869995
# 331   -18.859985
# 332     6.510010
# 333    14.169983
# Length: 334, dtype: float64

# %%
movements.plot()

# %% [markdown]
# # Lesson 02 ( Working with Missing Data)

# %% [markdown]
# ## Finding Missing Values using Python

# %%
df.isnull().sum()
# Out:
# Date                0
# Adj Close (TSLA)    0
# Adj Close (SEDG)    0
# Close (TSLA)        0
# Close (SEDG)        0
# High (TSLA)         0
# High (SEDG)         0
# Low (TSLA)          0
# Low (SEDG)          0
# Open (TSLA)         0
# Open (SEDG)         0
# Volume (TSLA)       0
# Volume (SEDG)       0
# dtype: int64

# %% [markdown]
# **Great News!** We do not have missing Values for this example

# %%
df
# Out:
#            Date  Adj Close (TSLA)  ...  Volume (TSLA)  Volume (SEDG)
# 0     7/11/2019         47.720001  ...       37572000         520000
# 1     7/12/2019         49.015999  ...       46002500         417500
# 2     7/15/2019         50.700001  ...       55000500         332800
# 3     7/16/2019         50.476002  ...       40745000         204000
# 4     7/17/2019         50.972000  ...       48823500         285300
# ..          ...               ...  ...            ...            ...
# 329  10/28/2020        406.019989  ...       25451400        1336400
# 330  10/29/2020        410.829987  ...       22655300        1099500
# 331  10/30/2020        388.040008  ...       42511300        1232700
# 332   11/2/2020        400.510010  ...       29021100        1805500
# 333   11/3/2020        423.899994  ...       34351700        8792700
#
# [334 rows x 13 columns]

# %% [markdown]
# Let's make a copy of our dataframe, so that if something goes wrong, we can always return for the original data

# %%
df_tmp = df

# %%
df_tmp
# Out:
#            Date  Adj Close (TSLA)  ...  Volume (TSLA)  Volume (SEDG)
# 0     7/11/2019         47.720001  ...       37572000         520000
# 1     7/12/2019         49.015999  ...       46002500         417500
# 2     7/15/2019         50.700001  ...       55000500         332800
# 3     7/16/2019         50.476002  ...       40745000         204000
# 4     7/17/2019         50.972000  ...       48823500         285300
# ..          ...               ...  ...            ...            ...
# 329  10/28/2020        406.019989  ...       25451400        1336400
# 330  10/29/2020        410.829987  ...       22655300        1099500
# 331  10/30/2020        388.040008  ...       42511300        1232700
# 332   11/2/2020        400.510010  ...       29021100        1805500
# 333   11/3/2020        423.899994  ...       34351700        8792700
#
# [334 rows x 13 columns]

# %%
len(df_tmp)
# Out:
# 334

# %%
df_tmp.shape
# Out:
# (334, 13)

# %% [markdown]
# # Lesson 03 (Feature Engineering)

# %% [markdown]
# `We will now find the best feature in our data and predict that data using Machine Learning`

# %% [markdown]
# > Finding correlation matrix

# %%
df_tmp.corr()
# Out:
#                   Adj Close (TSLA)  ...  Volume (SEDG)
# Adj Close (TSLA)          1.000000  ...       0.036497
# Adj Close (SEDG)          0.945488  ...       0.065018
# Close (TSLA)              1.000000  ...       0.036497
# Close (SEDG)              0.945488  ...       0.065018
# High (TSLA)               0.999094  ...       0.036477
# High (SEDG)               0.944007  ...       0.076859
# Low (TSLA)                0.998728  ...       0.040806
# Low (SEDG)                0.945731  ...       0.051731
# Open (TSLA)               0.997891  ...       0.038715
# Open (SEDG)               0.943744  ...       0.065687
# Volume (TSLA)             0.179792  ...      -0.017000
# Volume (SEDG)             0.036497  ...       1.000000
#
# [12 rows x 12 columns]

# %% [markdown]
# ***Let's visualize with seaborn heatmap***

# %% [markdown]
# Heatmap shows us the correlation matrix. We can find the feature which has the impotant relationship with all the data in our dataset.

# %% [markdown]
# Import the package first

# %%
import seaborn as sns

# %% [markdown]
# Let's view the data types of each columns

# %%
df_tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 334 entries, 0 to 333
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              334 non-null    object
#  1   Adj Close (TSLA)  334 non-null    float64
#  2   Adj Close (SEDG)  334 non-null    float64
#  3   Close (TSLA)      334 non-null    float64
#  4   Close (SEDG)      334 non-null    float64
#  5   High (TSLA)       334 non-null    float64
#  6   High (SEDG)       334 non-null    float64
#  7   Low (TSLA)        334 non-null    float64
#  8   Low (SEDG)        334 non-null    float64
#  9   Open (TSLA)       334 non-null    float64
#  10  Open (SEDG)       334 non-null    float64
#  11  Volume (TSLA)     334 non-null    int64
#  12  Volume (SEDG)     334 non-null    int64
# dtypes: float64(10), int64(2), object(1)
# memory usage: 34.0+ KB

# %% [markdown]
# Let's remove the Date column as it is a String and We are working with numbers

# %%
corr_df = df_tmp.drop("Date", axis=1)

# %%
corr_df
# Out:
#      Adj Close (TSLA)  Adj Close (SEDG)  ...  Volume (TSLA)  Volume (SEDG)
# 0           47.720001         60.759998  ...       37572000         520000
# 1           49.015999         62.119999  ...       46002500         417500
# 2           50.700001         61.830002  ...       55000500         332800
# 3           50.476002         61.400002  ...       40745000         204000
# 4           50.972000         62.360001  ...       48823500         285300
# ..                ...               ...  ...            ...            ...
# 329        406.019989        263.829987  ...       25451400        1336400
# 330        410.829987        270.089996  ...       22655300        1099500
# 331        388.040008        257.690002  ...       42511300        1232700
# 332        400.510010        267.720001  ...       29021100        1805500
# 333        423.899994        206.369995  ...       34351700        8792700
#
# [334 rows x 12 columns]

# %% [markdown]
# Do not for get to import Matplotlib Visualization Library

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (50,20))
sns.heatmap(corr_df,
                annot=True,
                linewidths=0.5,
                fmt=".2f",
                cmap="YlGnBu")

# %% [markdown]
# As we have so many data, we cannot preview the number, but we can plot the datafrme to find the most important feature

# %%
df_tmp.plot(figsize=(10,8))

# %% [markdown]
# It seems like Volume (TSLA) Has stronger features

# %%
plt.figure(figsize=(12, 8))
df_tmp['Volume (TSLA)'].plot()

# %% [markdown]
# # Lession 04 ( Model Creation)

# %%
df_tmp
# Out:
#            Date  Adj Close (TSLA)  ...  Volume (TSLA)  Volume (SEDG)
# 0     7/11/2019         47.720001  ...       37572000         520000
# 1     7/12/2019         49.015999  ...       46002500         417500
# 2     7/15/2019         50.700001  ...       55000500         332800
# 3     7/16/2019         50.476002  ...       40745000         204000
# 4     7/17/2019         50.972000  ...       48823500         285300
# ..          ...               ...  ...            ...            ...
# 329  10/28/2020        406.019989  ...       25451400        1336400
# 330  10/29/2020        410.829987  ...       22655300        1099500
# 331  10/30/2020        388.040008  ...       42511300        1232700
# 332   11/2/2020        400.510010  ...       29021100        1805500
# 333   11/3/2020        423.899994  ...       34351700        8792700
#
# [334 rows x 13 columns]

# %%
df_tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 334 entries, 0 to 333
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              334 non-null    object
#  1   Adj Close (TSLA)  334 non-null    float64
#  2   Adj Close (SEDG)  334 non-null    float64
#  3   Close (TSLA)      334 non-null    float64
#  4   Close (SEDG)      334 non-null    float64
#  5   High (TSLA)       334 non-null    float64
#  6   High (SEDG)       334 non-null    float64
#  7   Low (TSLA)        334 non-null    float64
#  8   Low (SEDG)        334 non-null    float64
#  9   Open (TSLA)       334 non-null    float64
#  10  Open (SEDG)       334 non-null    float64
#  11  Volume (TSLA)     334 non-null    int64
#  12  Volume (SEDG)     334 non-null    int64
# dtypes: float64(10), int64(2), object(1)
# memory usage: 34.0+ KB

# %% [markdown]
# ## Splitting DataFrame

# %% [markdown]
# Split our data for training and Testting

# %%
tesla = df_tmp['Volume (TSLA)']  #Selecting the TSLA (Volumne) column for prediciton
tesla_stock_prices = tesla.values.astype('float32') # Converting into tensors (Computational Optimized Number)
tesla_stock_prices = tesla_stock_prices.reshape(334, 1) # Reshaping 
tesla_stock_prices.shape
# Out:
# (334, 1)

# %%
tesla = df_tmp['Volume (TSLA)']

# %%
tesla.shape
# Out:
# (334,)

# %% [markdown]
# Importing the Scaler to Scale our data in a range of 0 to 1

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
plt.plot(tesla_stock_prices)
plt.show()

scaler = MinMaxScaler(feature_range=(0, 1))
tesla_stock_prices = scaler.fit_transform(tesla_stock_prices) #Training sets

# %% [markdown]
# The above graps proves that our data is alright after scaling

# %% [markdown]
# ## Splitting the dataset into Training and Testing

# %%
train_size = int(len(tesla_stock_prices) * 0.80)
test_size = len(tesla_stock_prices) - train_size
train, test = tesla_stock_prices[0:train_size,:], tesla_stock_prices[train_size:len(tesla_stock_prices),:]

# %%
len(test)
# Out:
# 67

# %%
len(train)
# Out:
# 267

# %% [markdown]
# This will convert the data into an array

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return np.array(dataX), np.array(dataY)

# %%
# reshape into X=t and Y=t+1
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# %%
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
trainX
# Out:
# array([[[0.09201875]],
#
#        [[0.12067507]],
#
#        [[0.1512604 ]],
#
#        [[0.10280417]],
#
#        [[0.13026401]],
#
#        [[0.0451822 ]],
#
#        [[0.08409879]],
#
#        [[0.08059769]],
#
#        [[0.04967754]],
#
#        [[0.152496  ]],
#
#        [[0.3453199 ]],
#
#        [[0.13473386]],
#
#        [[0.12191236]],
#
#        [[0.10212435]],
#
#        [[0.12029608]],
#
#        [[0.10468219]],
#
#        [[0.06860048]],
#
#        [[0.08375718]],
#
#        [[0.05887388]],
#
#        [[0.04548642]],
#
#        [[0.05394685]],
#
#        [[0.03055916]],
#
#        [[0.04357271]],
#
#        [[0.04670331]],
#
#        [[0.12682919]],
#
#        [[0.10298432]],
#
#        [[0.05095901]],
#
#        [[0.05454679]],
#
#        [[0.03441717]],
#
#        [[0.09677583]],
#
#        [[0.07578113]],
#
#        [[0.10942568]],
#
#        [[0.05016702]],
#
#        [[0.05635852]],
#
#        [[0.0191262 ]],
#
#        [[0.05233566]],
#
#        [[0.12271625]],
#
# ...

# %% [markdown]
# Import the model packages

# %%
from subprocess import check_output
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.models import Sequential
from sklearn.model_selection import train_test_split
import time #helper libraries

# %%
#Step 2 Build Model
model = Sequential()

model.add(LSTM(50, activation='relu')) # 50 RNN
model.add(Dense(1)) # Output Layer RNN
start = time.time()
model.compile(loss='mse', optimizer='rmsprop')
print ('compilation time : ', time.time() - start)
# Out:
# compilation time :  0.01424717903137207

# %% [markdown]
# Let's Run our model

# %%
model.fit(trainX, trainY, batch_size=1, epochs= 10,
    validation_split=0.05)
# Out:
# Epoch 1/10
# 251/251 [==============================] - 1s 2ms/step - loss: 0.0201 - val_loss: 0.0249
# Epoch 2/10
# 251/251 [==============================] - 0s 2ms/step - loss: 0.0154 - val_loss: 0.0268
# Epoch 3/10
# 251/251 [==============================] - 0s 2ms/step - loss: 0.0141 - val_loss: 0.0208
# Epoch 4/10
# 251/251 [==============================] - 0s 2ms/step - loss: 0.0121 - val_loss: 0.0189
# Epoch 5/10
# 251/251 [==============================] - 0s 2ms/step - loss: 0.0105 - val_loss: 0.0166
# Epoch 6/10
# 251/251 [==============================] - 0s 2ms/step - loss: 0.0098 - val_loss: 0.0174
# Epoch 7/10
# 251/251 [==============================] - 0s 1ms/step - loss: 0.0089 - val_loss: 0.0186
# Epoch 8/10
# 251/251 [==============================] - 0s 1ms/step - loss: 0.0089 - val_loss: 0.0168
# Epoch 9/10
# 251/251 [==============================] - 0s 1ms/step - loss: 0.0087 - val_loss: 0.0174
# Epoch 10/10
# ...

# %% [markdown]
# # Model Evaluation

# %%
model.history.history
# Out:
# {'loss': [0.020065097138285637,
#   0.015385277569293976,
#   0.01408187672495842,
#   0.012130232527852058,
#   0.010507100261747837,
#   0.009818385355174541,
#   0.008937983773648739,
#   0.008859655819833279,
#   0.008734106086194515,
#   0.008557773195207119],
#  'val_loss': [0.02485085465013981,
#   0.0268152616918087,
#   0.0208461731672287,
#   0.01891023851931095,
#   0.016598595306277275,
#   0.01735270582139492,
#   0.018595010042190552,
#   0.016847562044858932,
#   0.01741194538772106,
#   0.01685030572116375]}

# %% [markdown]
# Let's convert this into a Data frame

# %%
model_history = pd.DataFrame(model.history.history)

# %%
model_history
# Out:
#        loss  val_loss
# 0  0.020065  0.024851
# 1  0.015385  0.026815
# 2  0.014082  0.020846
# 3  0.012130  0.018910
# 4  0.010507  0.016599
# 5  0.009818  0.017353
# 6  0.008938  0.018595
# 7  0.008860  0.016848
# 8  0.008734  0.017412
# 9  0.008558  0.016850

# %%
model_history.plot()

# %% [markdown]
# # Predictions

# %%
from numpy import newaxis

# %%
def plot_results_multiple(predicted_data, true_data,length):
    plt.plot(scaler.inverse_transform(true_data.reshape(-1, 1))[length:])
    plt.plot(scaler.inverse_transform(np.array(predicted_data).reshape(-1, 1))[length:])
    plt.show()
    
#predict lenght consecutive values from a real one
def predict_sequences_multiple(model, firstValue,length):
    prediction_seqs = []
    curr_frame = firstValue
    
    for i in range(length): 
        predicted = []        
        
        print(model.predict(curr_frame[newaxis,:,:]))
        predicted.append(model.predict(curr_frame[newaxis,:,:])[0,0])
        
        curr_frame = curr_frame[0:]
        curr_frame = np.insert(curr_frame[0:], i+1, predicted[-1], axis=0)
        
        prediction_seqs.append(predicted[-1])
        
    return prediction_seqs

predict_length=1
predictions = predict_sequences_multiple(model, testX[0], predict_length)
print(scaler.inverse_transform(np.array(predictions).reshape(-1, 1)))
plot_results_multiple(predictions, testY, predict_length)
# Out:
# [[0.17112966]]
# [[60845900.]]

# %% [markdown]
# The predictions for next 60 days

# %% [markdown]
# # Let's use a different technique to make more accurate training

# %% [markdown]
# Reimport the data set but this time we will make it scaled so that our dates becomes number

# %%
df_new = pd.read_csv('/content/drive/My Drive/Data/stock_data_version_2.csv', parse_dates=True, index_col='Date')

# %%
df_new
# Out:
#             Adj Close (TSLA)  Adj Close (SEDG)  ...  Volume (TSLA)  Volume (SEDG)
# Date                                            ...
# 2019-07-11         47.720001         60.759998  ...       37572000         520000
# 2019-07-12         49.015999         62.119999  ...       46002500         417500
# 2019-07-15         50.700001         61.830002  ...       55000500         332800
# 2019-07-16         50.476002         61.400002  ...       40745000         204000
# 2019-07-17         50.972000         62.360001  ...       48823500         285300
# ...                      ...               ...  ...            ...            ...
# 2020-10-28        406.019989        263.829987  ...       25451400        1336400
# 2020-10-29        410.829987        270.089996  ...       22655300        1099500
# 2020-10-30        388.040008        257.690002  ...       42511300        1232700
# 2020-11-02        400.510010        267.720001  ...       29021100        1805500
# ...

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 334 entries, 2019-07-11 to 2020-11-03
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Adj Close (TSLA)  334 non-null    float64
#  1   Adj Close (SEDG)  334 non-null    float64
#  2   Close (TSLA)      334 non-null    float64
#  3   Close (SEDG)      334 non-null    float64
#  4   High (TSLA)       334 non-null    float64
#  5   High (SEDG)       334 non-null    float64
#  6   Low (TSLA)        334 non-null    float64
#  7   Low (SEDG)        334 non-null    float64
#  8   Open (TSLA)       334 non-null    float64
#  9   Open (SEDG)       334 non-null    float64
#  10  Volume (TSLA)     334 non-null    int64
#  11  Volume (SEDG)     334 non-null    int64
# dtypes: float64(10), int64(2)
# memory usage: 33.9 KB

# %% [markdown]
# Let's only work with the Date and Volumne (TSLA)

# %% [markdown]
# Delete the columns that we won't work with

# %%
df_new = df_new.drop('Adj Close (TSLA)', axis=1)

# %%
df_new
# Out:
#             Adj Close (SEDG)  Close (TSLA)  ...  Volume (TSLA)  Volume (SEDG)
# Date                                        ...
# 2019-07-11         60.759998     47.720001  ...       37572000         520000
# 2019-07-12         62.119999     49.015999  ...       46002500         417500
# 2019-07-15         61.830002     50.700001  ...       55000500         332800
# 2019-07-16         61.400002     50.476002  ...       40745000         204000
# 2019-07-17         62.360001     50.972000  ...       48823500         285300
# ...                      ...           ...  ...            ...            ...
# 2020-10-28        263.829987    406.019989  ...       25451400        1336400
# 2020-10-29        270.089996    410.829987  ...       22655300        1099500
# 2020-10-30        257.690002    388.040008  ...       42511300        1232700
# 2020-11-02        267.720001    400.510010  ...       29021100        1805500
# ...

# %%
df_new.columns
# Out:
# Index(['Adj Close (SEDG)', 'Close (TSLA)', 'Close (SEDG) ', 'High (TSLA)',
#        'High (SEDG)', 'Low (TSLA)', 'Low (SEDG)', 'Open (TSLA)', 'Open (SEDG)',
#        'Volume (TSLA)', 'Volume (SEDG)'],
#       dtype='object')

# %%
df_new = df_new.drop(['Adj Close (SEDG)', 'Close (TSLA)', 'Close (SEDG) ', 'High (TSLA)',
       'High (SEDG)', 'Low (TSLA)', 'Low (SEDG)', 'Open (TSLA)', 'Open (SEDG)', 'Volume (SEDG)'], axis=1)

# %%
df_new
# Out:
#             Volume (TSLA)
# Date
# 2019-07-11       37572000
# 2019-07-12       46002500
# 2019-07-15       55000500
# 2019-07-16       40745000
# 2019-07-17       48823500
# ...                   ...
# 2020-10-28       25451400
# 2020-10-29       22655300
# 2020-10-30       42511300
# 2020-11-02       29021100
# 2020-11-03       34351700
#
# [334 rows x 1 columns]

# %% [markdown]
# Now we only have date and the column we wanted to predict

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 334 entries, 2019-07-11 to 2020-11-03
# Data columns (total 1 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Volume (TSLA)  334 non-null    int64
# dtypes: int64(1)
# memory usage: 5.2 KB

# %% [markdown]
# Let's define our test_size

# %%
len(df_new) - 18
# Out:
# 316

# %%
test_size = 18
test_ind = len(df_new) - test_size

# %%
train = df_new.iloc[:test_ind]

# %%
train
# Out:
#             Volume (TSLA)
# Date
# 2019-07-11       37572000
# 2019-07-12       46002500
# 2019-07-15       55000500
# 2019-07-16       40745000
# 2019-07-17       48823500
# ...                   ...
# 2020-10-02       71430000
# 2020-10-05       44722800
# 2020-10-06       49146300
# 2020-10-07       43127700
# 2020-10-08       40421100
#
# [316 rows x 1 columns]

# %%
test = df_new.iloc[test_ind:]

# %%
test
# Out:
#             Volume (TSLA)
# Date
# 2020-10-09       28925700
# 2020-10-12       38791100
# 2020-10-13       34463700
# 2020-10-14       48045400
# 2020-10-15       35672400
# 2020-10-16       32775900
# 2020-10-19       36287800
# 2020-10-20       31656300
# 2020-10-21       32370500
# 2020-10-22       39993200
# 2020-10-23       33717000
# 2020-10-26       28239200
# 2020-10-27       22686500
# 2020-10-28       25451400
# 2020-10-29       22655300
# 2020-10-30       42511300
# 2020-11-02       29021100
# 2020-11-03       34351700

# %% [markdown]
# Scale the data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(train)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
scaled_train = scaler.transform(train)

# %%
scaled_test = scaler.transform(test)

# %% [markdown]
# Let's create the time series generator

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
len(test)
# Out:
# 18

# %% [markdown]
# The batches should be shorter than 18.
# We will take 12 but you can take any number you want.

# %%
length = 12
generator = TimeseriesGenerator(scaled_train, scaled_train, length=length, batch_size=1)

# %%
X,y = generator[0]

# %%
X
# Out:
# array([[[0.09201875],
#         [0.12067508],
#         [0.15126041],
#         [0.10280418],
#         [0.13026401],
#         [0.0451822 ],
#         [0.08409879],
#         [0.08059769],
#         [0.04967754],
#         [0.15249599],
#         [0.3453199 ],
#         [0.13473386]]])

# %%
y
# Out:
# array([[0.12191236]])

# %%
len(X[0])
# Out:
# 12

# %% [markdown]
# We will predict the next 13th day

# %% [markdown]
# # Creating a Better Model

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense,LSTM

# %%
n_features = 1

# %%
model = Sequential()
model.add(LSTM(150,activation='relu',input_shape=(length,n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_2 (LSTM)                (None, 150)               91200
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 151
# ...
# Total params: 91,351
# Trainable params: 91,351
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Let's import Early stopping to make the model more efficient

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=2)

# %%
validation_generator = TimeseriesGenerator(scaled_test, scaled_test,
                                           length=length, batch_size = 1)

# %%
model.fit_generator(generator, epochs=20,
                    validation_data=validation_generator,
                    callbacks=[early_stop])
# Out:
# WARNING:tensorflow:From <ipython-input-99-43ca1824ec30>:3: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/20
# 304/304 [==============================] - 3s 8ms/step - loss: 0.0146 - val_loss: 0.0038
# Epoch 2/20
# 304/304 [==============================] - 2s 7ms/step - loss: 0.0118 - val_loss: 8.8915e-04
# Epoch 3/20
# 304/304 [==============================] - 2s 8ms/step - loss: 0.0114 - val_loss: 0.0016
# Epoch 4/20
# 304/304 [==============================] - 2s 8ms/step - loss: 0.0105 - val_loss: 7.8982e-04
# Epoch 5/20
# 304/304 [==============================] - 2s 8ms/step - loss: 0.0102 - val_loss: 0.0025
# Epoch 6/20
# 304/304 [==============================] - 2s 8ms/step - loss: 0.0100 - val_loss: 0.0010

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()

# %% [markdown]
# Predictions

# %%
test_predictions = []

first_eval_batch = scaled_train[-length:]
current_batch = first_eval_batch.reshape((1,length, n_features))

for i in range(len(test)):

  # Get prediction 1 time stamp ahead
  current_pred = model.predict(current_batch)[0]

  # store predictions
  test_predictions.append(current_pred)

  # update batch to now include predictions and drop first value
  current_batch = np.append(current_batch[:,1:,:],[[current_pred]], axis=1)

# %%
true_predictions = scaler.inverse_transform(test_predictions)

# %%
test['Predictions'] = true_predictions
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
test
# Out:
#             Volume (TSLA)   Predictions
# Date
# 2020-10-09       28925700  4.705795e+07
# 2020-10-12       38791100  4.813594e+07
# 2020-10-13       34463700  4.903187e+07
# 2020-10-14       48045400  4.982744e+07
# 2020-10-15       35672400  5.053663e+07
# 2020-10-16       32775900  5.118278e+07
# 2020-10-19       36287800  5.176964e+07
# 2020-10-20       31656300  5.234697e+07
# 2020-10-21       32370500  5.295619e+07
# 2020-10-22       39993200  5.350733e+07
# 2020-10-23       33717000  5.404599e+07
# 2020-10-26       28239200  5.456739e+07
# 2020-10-27       22686500  5.504837e+07
# 2020-10-28       25451400  5.550036e+07
# 2020-10-29       22655300  5.592621e+07
# 2020-10-30       42511300  5.632721e+07
# 2020-11-02       29021100  5.670380e+07
# 2020-11-03       34351700  5.705472e+07

# %%
test.plot(figsize=(12,8))

# %% [markdown]
# Predictions on full set

# %%
full_scaler = MinMaxScaler()
scaled_full_data = full_scaler.fit_transform(df_new)

# %%
length = 12
generator = TimeseriesGenerator(scaled_full_data, scaled_full_data,
                                length=length, batch_size=1)

# %%
model = Sequential()
model.add(LSTM(100, activation='relu', input_shape=(length, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

model.fit_generator(generator, epochs=8)
# Out:
# Epoch 1/8
# 322/322 [==============================] - 2s 5ms/step - loss: 0.0134
# Epoch 2/8
# 322/322 [==============================] - 2s 5ms/step - loss: 0.0113
# Epoch 3/8
# 322/322 [==============================] - 2s 5ms/step - loss: 0.0108
# Epoch 4/8
# 322/322 [==============================] - 2s 5ms/step - loss: 0.0102
# Epoch 5/8
# 322/322 [==============================] - 2s 5ms/step - loss: 0.0102
# Epoch 6/8
# 322/322 [==============================] - 2s 5ms/step - loss: 0.0095
# Epoch 7/8
# 322/322 [==============================] - 2s 5ms/step - loss: 0.0090
# Epoch 8/8
# 322/322 [==============================] - 2s 5ms/step - loss: 0.0090

# %%
forecast = []

# Replace the period with whatever forecast length you want
periods = 12

first_eval_batch = scaled_train[-length:]
current_batch = first_eval_batch.reshape((1,length, n_features))

for i in range(periods):

  # Get prediction 1 time stamp ahead
  current_pred = model.predict(current_batch)[0]

  # store predictions
  forecast.append(current_pred)

  # update batch to now include predictions and drop first value
  current_batch = np.append(current_batch[:,1:,:],[[current_pred]], axis=1)

# %%
forecast = scaler.inverse_transform(forecast)

# %%
df_new
# Out:
#             Volume (TSLA)
# Date
# 2019-07-11       37572000
# 2019-07-12       46002500
# 2019-07-15       55000500
# 2019-07-16       40745000
# 2019-07-17       48823500
# ...                   ...
# 2020-10-28       25451400
# 2020-10-29       22655300
# 2020-10-30       42511300
# 2020-11-02       29021100
# 2020-11-03       34351700
#
# [334 rows x 1 columns]

# %% [markdown]
# Let's predict what will be the data after **2020-11-03**

# %%
forecast
# Out:
# array([[40023565.34940004],
#        [38684417.38948971],
#        [37641444.81322616],
#        [36588420.13360858],
#        [35408913.42783719],
#        [34262180.17373383],
#        [33086358.07017311],
#        [32003291.05985984],
#        [31339451.11880004],
#        [30491291.19886011],
#        [29758237.28754073],
#        [29049191.37622938]])

# %%
forecast_index = pd.date_range(start='2020-11-04', periods=periods,
                               freq="MS")

# %%
forecast_index
# Out:
# DatetimeIndex(['2020-12-01', '2021-01-01', '2021-02-01', '2021-03-01',
#                '2021-04-01', '2021-05-01', '2021-06-01', '2021-07-01',
#                '2021-08-01', '2021-09-01', '2021-10-01', '2021-11-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
forecast_df = pd.DataFrame(data=forecast, index=forecast_index,
                           columns=['Forecast'])

# %%
df_new.plot()
forecast_df.plot()

# %% [markdown]
# View on same plot

# %%
ax = df_new.plot()
forecast_df.plot(ax=ax)
